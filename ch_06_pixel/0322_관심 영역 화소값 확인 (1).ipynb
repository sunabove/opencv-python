# %%
# 관심 영역 화소값 확인
import numpy as np, cv2, matplotlib.pyplot as plt

 # 영상 읽기 
all_image = cv2.imread("example.jpg", cv2.IMREAD_GRAYSCALE)

(x, y), (width, height) = (180, 37), (15, 10) # 좌표는 x, y
roi_img = all_image[ y : y + height , x : x + width ] # 행렬 접근은 y, x

print("roi image pixel data =")

for row in roi_img:
    for p in row:
        print("%4d" % p, end="")       # 행렬 원 하나 출력
    pass
    print()
pass
print()

plt.title('ROI Image')
plt.imshow( roi_img, cmap="gray") 
plt.axis('off') 
plt.show()
# Out:
# roi image pixel data =
#  201 202 202 202 201 201 201 202 203 204 203 203 201 201 201
#  202 202 203 203 202 202 202 202 204 204 204 203 201 201 202
#  202 203 204 204 203 202 202 203 204 204 204 203 202 202 202
#  203 203 203 203 202 202 202 202 203 204 203 202 203 202 201
#  202 202 202 202 202 202 201 202 203 204 203 202 203 202 201
#  202 201 201 201 202 202 201 202 203 203 203 202 203 203 202
#  201 201 200 200 202 201 201 201 202 203 203 202 203 203 202
#  201 201 200 200 202 201 201 201 202 203 203 202 203 203 203
#  202 201 201 200 202 201 200 200 202 203 203 203 204 203 203
#  202 202 201 201 202 201 200 200 201 202 203 203 204 204 204
